# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer

import sys
sys.path.append('../')
from helpers import *

# %%
data_path = './../../../data'
advocate_dir = os.path.join(data_path, 'BeerAdvocate')
stems_ba = pd.read_pickle(os.path.join(advocate_dir, 'reviews_with_exp_stems.pkl'))
stems_ba.columns = ['appearance_rt' if i == 9 else col for i, col in enumerate(stems_ba.columns)]
expert_categories = get_exp_categories(data_path)
expert_terms_stemmed = get_exp_stems(data_path)

# %%
def score_df(df, expert_categories, expert_terms_stemmed):
    for criterion in expert_categories:
        df[criterion] = df['stems'].apply(lambda cell: len(list(set(cell) & set(expert_terms_stemmed[criterion]))))
    df['expertness_score'] = df[expert_categories].sum(axis=1)
    return df

# %%
reviews_Stout = stems_ba[stems_ba['beer_id']==11757]

# %%
import time

start_time = time.time()

df_stout = score_df(reviews_Stout, expert_categories, expert_terms_stemmed)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.03595709800720215 seconds ---
# /var/folders/y0/lnx9fwjn5c75w4wndjtsp_4h0000gn/T/ipykernel_25606/4205428389.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[criterion] = df['stems'].apply(lambda cell: len(list(set(cell) & set(expert_terms_stemmed[criterion]))))
# /var/folders/y0/lnx9fwjn5c75w4wndjtsp_4h0000gn/T/ipykernel_25606/4205428389.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[criterion] = df['stems'].apply(lambda cell: len(list(set(cell) & set(expert_terms_stemmed[criterion]))))
# /var/folders/y0/lnx9fwjn5c75w4wndjtsp_4h0000gn/T/ipykernel_25606/4205428389.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[criterion] = df['stems'].apply(lambda cell: len(list(set(cell) & set(expert_terms_stemmed[criterion]))))
# /var/folders/y0/lnx9fwjn5c75w4wndjtsp_4h0000gn/T/ipykernel_25606/4205428389.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[criterion] = df['stems'].apply(lambda cell: len(list(set(cell) & set(expert_terms_stemmed[criterion]))))
# /var/folders/y0/lnx9fwjn5c75w4wndjtsp_4h0000gn/T/ipykernel_25606/4205428389.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[criterion] = df['stems'].apply(lambda cell: len(list(set(cell) & set(expert_terms_stemmed[criterion]))))
# /var/folders/y0/lnx9fwjn5c75w4wndjtsp_4h0000gn/T/ipykernel_25606/4205428389.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[criterion] = df['stems'].apply(lambda cell: len(list(set(cell) & set(expert_terms_stemmed[criterion]))))
# /var/folders/y0/lnx9fwjn5c75w4wndjtsp_4h0000gn/T/ipykernel_25606/4205428389.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['expertness_score'] = df[expert_categories].sum(axis=1)

# %%
import time

start_time = time.time()

df_ba = score_df(stems_ba, expert_categories, expert_terms_stemmed)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 335.85556197166443 seconds ---

# %%
df_ba.to_pickle(os.path.join(advocate_dir, 'rev_w_scores.pkl'))
df_ba.head()
# Out:
#        beer_name  beer_id                               brewery_name  \
# 0          Régab   142544  Societe des Brasseries du Gabon (SOBRAGA)
# 1  Barelegs Brew    19590       Strangford Lough Brewing Company Ltd
# 2  Barelegs Brew    19590       Strangford Lough Brewing Company Ltd
# 3  Barelegs Brew    19590       Strangford Lough Brewing Company Ltd
# 4  Barelegs Brew    19590       Strangford Lough Brewing Company Ltd
#
#    brewery_id             style  abv        date        user_name  \
# 0       37262   Euro Pale Lager  4.5  2015-08-20          nmann08
# 1       10093  English Pale Ale  4.5  2009-02-20      StJamesGate
# 2       10093  English Pale Ale  4.5  2006-03-13          mdagnew
# 3       10093  English Pale Ale  4.5  2004-12-01  helloloser12345
# 4       10093  English Pale Ale  4.5  2004-08-30       cypressbob
#
#                  user_id appearance  ...  review  lang_tag  \
# 0         nmann08.184925       3.25  ...    True        en
# 1     stjamesgate.163714       3.00  ...    True        en
# 2          mdagnew.19527       4.00  ...    True        en
# 3  helloloser12345.10867       4.00  ...    True        en
# 4        cypressbob.3708       4.00  ...    True        en
#
#                                                stems  flavor  mouthfeel  \
# 0  [floral, fizzi, straw, yellow, carbon, earthi,...       2          2
# 1  [copper, dri, thin, caramel, grassi, hop, dark...       4          2
# 2  [pepperi, fruiti, spici, thick, burnt, breadi,...      11          6
# 3  [hay, bitter, cloudi, balanc, lace, hoppi, subtl]       4          0
# 4  [floral, tan, malt, bodi, balanc, hop, hoppi, ...       2          1
#
#    brewing technical appearance  off_flavors  expertness_score
# 0        2         0          2            1                 9
# 1        3         0          2            1                12
# 2        2         1          2            1                23
# 3        0         1          2            0                 7
# 4        2         1          4            0                10
#
# [5 rows x 25 columns]

# %%
del df_ba

# %%
data_path = './../../../data'
rb_dir = os.path.join(data_path, 'RateBeer')
stems_rb = pd.read_pickle(os.path.join(rb_dir, 'reviews_with_exp_stems.pkl'))
expert_categories = get_exp_categories(data_path)
expert_terms_stemmed = get_exp_stems(data_path)
stems_rb.columns = ['appearance_rt' if i == 9 else col for i, col in enumerate(stems_rb.columns)]

# %%
import time
start_time = time.time()

df_rb = score_df(stems_rb, expert_categories, expert_terms_stemmed)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 45.55741906166077 seconds ---

# %%
df_rb.to_pickle(os.path.join(rb_dir, 'rev_w_scores.pkl'))
df_rb.head()
# Out:
#              beer_name  beer_id brewery_name  brewery_id       style  abv  \
# 4  Castel Beer (Gabon)   105273      Sobraga        3198  Pale Lager  5.2
# 5  Castel Beer (Gabon)   105273      Sobraga        3198  Pale Lager  5.2
# 6  Castel Beer (Gabon)   105273      Sobraga        3198  Pale Lager  5.2
# 8  Castel Beer (Gabon)   105273      Sobraga        3198  Pale Lager  5.2
# 9  Castel Beer (Gabon)   105273      Sobraga        3198  Pale Lager  5.2
#
#          date      user_name  user_id  appearance_rt  ...  review  lang_tag  \
# 4  2015-10-23     kevnic2008   122778            2.0  ...    True        en
# 5  2015-10-12  Beerhunter111   227834            2.0  ...    True        en
# 6  2015-10-07       Erzengel    83106            4.0  ...    True        en
# 8  2014-05-29      Lowenbrau    37316            3.0  ...    True        en
# 9  2013-07-18         seynie    75452            2.0  ...    True        en
#
#                                                stems  flavor  mouthfeel  \
# 4               [crisp, finish, bodi, carbon, light]       0          2
# 5          [finish, clear, grain, hop, malt, wateri]       0          1
# 6                             [bitter, bodi, smooth]       1          2
# 8  [skunki, bright, bodi, clear, lace, carbon, ad...       0          2
# 9                 [foam, malti, bodi, yellow, light]       1          1
#
#    brewing technical appearance  off_flavors  expertness_score
# 4        0         2          1            0                 5
# 5        3         1          1            0                 6
# 6        0         0          0            0                 3
# 8        1         0          5            1                 9
# 9        0         0          3            0                 5
#
# [5 rows x 25 columns]

# %%
del df_rb
